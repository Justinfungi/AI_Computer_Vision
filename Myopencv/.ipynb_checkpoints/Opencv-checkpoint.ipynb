# %%
import cv2 as cv

img = cv.imread('/Users/zhangdemei/Desktop/ProgrammingAtom/Myopencv/Resources/Photos/park.jpg')

cv.imshow('Cat', img)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b98c54b95a03> in <module>
#       5 cv.imshow('Cat', img)
#       6
# ----> 7 cv.waitKey(0)
#       8 cv.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
import cv2 as cv
import numpy as np
import matplotlib as plt
# %matplotlib inline
import Ipython.display as Image

# %%
import cv2 as cv
import numpy as np
np.set_printoptions(threshold=np.inf)
img = cv.imread(
    '/Users/zhangdemei/Desktop/ProgrammingAtom/Myopencv/Resources/Photos/park.jpg',0)
#print grey scale
print(img)
# Out:
# [[144 144 144 144 144 143 143 143 142 142 142 142 141 141 141 141 142 142
#   141 141 140 140 141 141 140 140 140 141 141 141 141 141 140 140 140 140
#   140 140 140 140 141 141 141 141 141 141 141 141 141 141 141 141 142 142
#   142 142 142 142 142 142 142 142 142 142 142 142 143 143 144 145 145 145
#   145 145 145 145 145 145 145 145 147 147 147 147 148 148 148 148 150 150
#   150 151 151 151 152 152 152 152 152 152 153 153 153 153 153 153 153 152
#   152 152 152 152 151 152 152 152 153 153 153 153 156 156 156 156 156 157
#   157 157 157 157 157 157 157 157 157 157 156 156 156 156 156 156 156 156
#   154 154 154 155 155 155 155 155 157 157 157 158 158 159 159 160 159 159
#   159 158 158 157 157 157 155 155 155 155 156 156 156 156 156 156 156 156
#   156 156 156 156 159 158 158 157 157 156 156 156 155 155 155 155 155 155
#   155 155 156 156 156 156 156 156 156 156 156 156 155 155 155 154 154 154
#   155 155 155 154 154 154 154 155 153 153 152 152 152 151 151 151 150 150
# ...
